# %%
import dataclasses

import jax

from openpi.models import model as _model
from openpi.policies import droid_policy
from openpi.policies import policy_config as _policy_config
from openpi.shared import download
from openpi.training import config as _config
from openpi.training import data_loader as _data_loader

# %% [markdown]
# # Policy inference
#
# The following example shows how to create a policy from a checkpoint and run inference on a dummy example.

# %%
import tensorflow_datasets as tfds
import numpy as np
from PIL import Image
from IPython import display

def as_gif(images, path="temp.gif"):
  # Render the images as the gif (15Hz control frequency):
  images[0].save(path, save_all=True, append_images=images[1:], duration=int(1000/15), loop=0)
  gif_bytes = open(path,"rb").read()
  return gif_bytes


ds = tfds.load("droid_100", data_dir="gs://gresearch/robotics", split="train")

actions = []
positions = []
for episode in ds:
  for i, step in enumerate(episode["steps"]):
    actions.append(step['action'])
    positions.append(step['action_dict']['joint_position'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 13
#       9   gif_bytes = open(path,"rb").read()
#      10   return gif_bytes
# ---> 13 ds = tfds.load("droid_100", data_dir="gs://gresearch/robotics", split="train")
#      15 actions = []
#      16 positions = []
#
# File ~/openpi/.venv/lib/python3.11/site-packages/tensorflow_datasets/core/logging/__init__.py:176, in _FunctionDecorator.__call__(self, function, instance, args, kwargs)
#     174 metadata = self._start_call()
#     175 try:
# --> 176   return function(*args, **kwargs)
#     177 except Exception:
#     178   metadata.mark_error()
#
# File ~/openpi/.venv/lib/python3.11/site-packages/tensorflow_datasets/core/load.py:660, in load(name, split, data_dir, batch_size, shuffle_files, download, as_supervised, decoders, read_config, with_info, builder_kwargs, download_and_prepare_kwargs, as_dataset_kwargs, try_gcs, file_format)
#     521 @tfds_logging.load()
#     522 def load(
#     523     name: str,
#    (...)    539 ):
#     540   # pylint: disable=line-too-long
#     541   """Loads the named dataset into a `tf.data.Dataset`.
#     542
#     543   `tfds.load` is a convenience method that:
#    (...)    658       Split-specific information is available in `ds_info.splits`.
#     659   """  # fmt: skip
# --> 660   dbuilder = _fetch_builder(
#     661       name=name,
#     662       data_dir=data_dir,
#     663       builder_kwargs=builder_kwargs,
#     664       try_gcs=try_gcs,
#     665   )
#     666   _download_and_prepare_builder(dbuilder, download, download_and_prepare_kwargs)
#     668   if as_dataset_kwargs is None:
#
# File ~/openpi/.venv/lib/python3.11/site-packages/tensorflow_datasets/core/load.py:495, in _fetch_builder(name, data_dir, builder_kwargs, try_gcs, file_format)
#     493 if file_format is not None:
#     494   builder_kwargs['file_format'] = file_format
# --> 495 return builder(name, data_dir=data_dir, try_gcs=try_gcs, **builder_kwargs)
#
# File /usr/licensed/anaconda3/2024.2/lib/python3.11/contextlib.py:81, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      78 @wraps(func)
#      79 def inner(*args, **kwds):
#      80     with self._recreate_cm():
# ---> 81         return func(*args, **kwds)
#
# File ~/openpi/.venv/lib/python3.11/site-packages/tensorflow_datasets/core/logging/__init__.py:176, in _FunctionDecorator.__call__(self, function, instance, args, kwargs)
#     174 metadata = self._start_call()
#     175 try:
# --> 176   return function(*args, **kwargs)
#     177 except Exception:
#     178   metadata.mark_error()
#
# File ~/openpi/.venv/lib/python3.11/site-packages/tensorflow_datasets/core/load.py:206, in builder(name, try_gcs, **builder_kwargs)
#     204 if _try_load_from_files_first(cls, **builder_kwargs):
#     205   try:
# --> 206     return read_only_builder.builder_from_files(str(name), **builder_kwargs)
#     207   except registered.DatasetNotFoundError as e:
#     208     logging.info(
#     209         'Failed to load %s from files: %s', get_dataset_repr(), str(e)
#     210     )
#
# File /usr/licensed/anaconda3/2024.2/lib/python3.11/contextlib.py:81, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      78 @wraps(func)
#      79 def inner(*args, **kwds):
#      80     with self._recreate_cm():
# ---> 81         return func(*args, **kwds)
#
# File ~/openpi/.venv/lib/python3.11/site-packages/tensorflow_datasets/core/read_only_builder.py:317, in builder_from_files(name, **builder_kwargs)
#     294 """Loads a `tfds.core.DatasetBuilder` from files, auto-inferring location.
#     295
#     296 This function is similar to `tfds.builder` (same signature), but creates
#    (...)    314   DatasetNotFoundError: If the dataset cannot be loaded.
#     315 """
#     316 # Find and load dataset builder.
# --> 317 builder_dir = _find_builder_dir(name, **builder_kwargs)
#     318 if builder_dir is None:
#     319   data_dirs = file_utils.list_data_dirs(
#     320       given_data_dir=builder_kwargs.get('data_dir')
#     321   )
#
# File ~/openpi/.venv/lib/python3.11/site-packages/tensorflow_datasets/core/read_only_builder.py:396, in _find_builder_dir(name, **builder_kwargs)
#     394 if len(all_data_dirs) <= 1:
#     395   for current_data_dir in all_data_dirs:
# --> 396     if builder_dir := find_builder_fn(data_dir=current_data_dir):
#     397       all_builder_dirs.add(builder_dir)
#     398 else:
#
# File ~/openpi/.venv/lib/python3.11/site-packages/tensorflow_datasets/core/read_only_builder.py:495, in _find_builder_dir_single_dir(data_dir, builder_name, config_name, version)
#     492 # If no config_name or an empty string was given, we try to find the default
#     493 # config and load the dataset for that.
#     494 if not config_name:
# --> 495   config_name = _get_default_config_name(
#     496       data_dir=data_dir, builder_name=builder_name
#     497   )
#     498   if version_lib.Version.is_valid(version):
#     499     dataset_dir = file_utils.get_dataset_dir(
#     500         data_dir=data_dir,
#     501         builder_name=builder_name,
#     502         config_name=config_name,
#     503         version=version,
#     504     )
#
# File ~/openpi/.venv/lib/python3.11/site-packages/tensorflow_datasets/core/read_only_builder.py:560, in _get_default_config_name(data_dir, builder_name)
#     557     return cls.default_builder_config.name
#     559 # Otherwise, try to load default config from common metadata
# --> 560 return dataset_builder.load_default_config_name(builder_dir)
#
# File ~/openpi/.venv/lib/python3.11/site-packages/tensorflow_datasets/core/dataset_builder.py:2060, in load_default_config_name(builder_dir)
#    2058 """Load `builder_cls` metadata (common to all builder configs)."""
#    2059 config_path = builder_dir / ".config" / constants.METADATA_FILENAME
# -> 2060 if not config_path.exists():
#    2061   return None
#    2062 data = json.loads(config_path.read_text())
#
# File ~/openpi/.venv/lib/python3.11/site-packages/etils/epath/gpath.py:152, in _GPath.exists(self)
#     150 def exists(self) -> bool:
#     151   """Returns True if self exists."""
# --> 152   return self._backend.exists(self._path_str)
#
# File ~/openpi/.venv/lib/python3.11/site-packages/etils/epath/backend.py:278, in _TfBackend.exists(self, path)
#     277 def exists(self, path: PathLike) -> bool:
# --> 278   return self.gfile.exists(path)
#
# File ~/openpi/.venv/lib/python3.11/site-packages/etils/epath/backend.py:263, in _TfBackend.gfile(self)
#     261 @property
#     262 def gfile(self):
# --> 263   return self.tf.io.gfile
#
# File ~/openpi/.venv/lib/python3.11/site-packages/etils/epath/backend.py:254, in _TfBackend.tf(self)
#     251 @property
#     252 def tf(self):
#     253   try:
# --> 254     import tensorflow  # pylint: disable=g-import-not-at-top  # pytype: disable=import-error
#     255   except ImportError as e:
#     256     raise ImportError(
#     257         f'{e}. To use epath.Path with gs://, TensorFlow should be installed.'
#     258     ) from None
#
# File ~/openpi/.venv/lib/python3.11/site-packages/tensorflow/__init__.py:49
#      46 from tensorflow.python import tf2 as _tf2
#      47 _tf2.enable()
# ---> 49 from tensorflow._api.v2 import __internal__
#      50 from tensorflow._api.v2 import __operators__
#      51 from tensorflow._api.v2 import audio
#
# File ~/openpi/.venv/lib/python3.11/site-packages/tensorflow/_api/v2/__internal__/__init__.py:8
#       3 """Public API for tf._api.v2.__internal__ namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.__internal__ import autograph
#       9 from tensorflow._api.v2.__internal__ import decorator
#      10 from tensorflow._api.v2.__internal__ import dispatch
#
# File ~/openpi/.venv/lib/python3.11/site-packages/tensorflow/_api/v2/__internal__/autograph/__init__.py:8
#       3 """Public API for tf._api.v2.__internal__.autograph namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow.python.autograph.core.ag_ctx import control_status_ctx # line: 34
#       9 from tensorflow.python.autograph.impl.api import tf_convert # line: 493
#
# File ~/openpi/.venv/lib/python3.11/site-packages/tensorflow/python/autograph/core/ag_ctx.py:21
#      18 import inspect
#      19 import threading
# ---> 21 from tensorflow.python.autograph.utils import ag_logging
#      22 from tensorflow.python.util.tf_export import tf_export
#      25 stacks = threading.local()
#
# File ~/openpi/.venv/lib/python3.11/site-packages/tensorflow/python/autograph/utils/__init__.py:17
#       1 # Copyright 2016 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)     13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Utility module that contains APIs usable in the generated code."""
# ---> 17 from tensorflow.python.autograph.utils.context_managers import control_dependency_on_returns
#      18 from tensorflow.python.autograph.utils.misc import alias_tensors
#      19 from tensorflow.python.autograph.utils.tensor_list import dynamic_list_append
#
# File ~/openpi/.venv/lib/python3.11/site-packages/tensorflow/python/autograph/utils/context_managers.py:19
#      15 """Various context managers."""
#      17 import contextlib
# ---> 19 from tensorflow.python.framework import ops
#      20 from tensorflow.python.ops import tensor_array_ops
#      23 def control_dependency_on_returns(return_value):
#
# File ~/openpi/.venv/lib/python3.11/site-packages/tensorflow/python/framework/ops.py:50
#      48 from tensorflow.python import tf2
#      49 from tensorflow.python.client import pywrap_tf_session
# ---> 50 from tensorflow.python.eager import context
#      51 from tensorflow.python.eager import core
#      52 from tensorflow.python.eager import monitoring
#
# File ~/openpi/.venv/lib/python3.11/site-packages/tensorflow/python/eager/context.py:38
#      36 from tensorflow.python.client import pywrap_tf_session
#      37 from tensorflow.python.eager import cancellation
# ---> 38 from tensorflow.python.eager import execute
#      39 from tensorflow.python.eager import executor
#      40 from tensorflow.python.eager import monitoring
#
# File ~/openpi/.venv/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:21
#      19 from tensorflow.python import pywrap_tfe
#      20 from tensorflow.python.eager import core
# ---> 21 from tensorflow.python.framework import dtypes
#      22 from tensorflow.python.framework import tensor_conversion_registry
#      23 from tensorflow.python.framework import tensor_shape
#
# File ~/openpi/.venv/lib/python3.11/site-packages/tensorflow/python/framework/dtypes.py:290
#     287   def __reduce__(self):
#     288     return as_dtype, (self.name,)
# --> 290 trace_type.register_serializable(DType)
#     292 # Define data type range of numpy dtype
#     293 dtype_range = {
#     294     np.bool_: (False, True),
#     295     np.uint8: (0, 255),
#    (...)    304     np.float64: (-1, 1),
#     305 }
#
# File ~/openpi/.venv/lib/python3.11/site-packages/tensorflow/core/function/trace_type/serialization.py:58, in register_serializable(cls)
#      50 """Registers a Python class to support serialization.
#      51
#      52 Only register standard TF types. Custom types should NOT be registered.
#    (...)     55   cls: Python class to register.
#      56 """
#      57 if cls.experimental_type_proto() in PROTO_CLASS_TO_PY_CLASS:
# ---> 58   raise ValueError(
#      59       "Existing Python class " +
#      60       PROTO_CLASS_TO_PY_CLASS[cls.experimental_type_proto()].__name__ +
#      61       " already has " + cls.experimental_type_proto().__name__ +
#      62       " as its associated proto representation. Please ensure " +
#      63       cls.__name__ + " has a unique proto representation.")
#      65 PROTO_CLASS_TO_PY_CLASS[cls.experimental_type_proto()] = cls
#
# ValueError: Existing Python class DType already has SerializedDType as its associated proto representation. Please ensure DType has a unique proto representation.

# %%
config = _config.get_config("pi0_fast_droid")
checkpoint_dir = download.maybe_download("gs://openpi-assets/checkpoints/pi0_fast_droid")

# Create a trained policy.
policy = _policy_config.create_trained_policy(config, checkpoint_dir)

# Run inference on a dummy example. This example corresponds to observations produced by the DROID runtime.
example = droid_policy.make_droid_example()
result = policy.infer(example)

# Delete the policy to free up memory.
del policy

print("Actions shape:", result["actions"].shape)
# Out:
#   0%|          | 0.00/10.1G [00:00<?, ?iB/s]
#   0%|          | 0.00/4.07M [00:00<?, ?iB/s]
# processor_config.json:   0%|          | 0.00/253 [00:00<?, ?B/s]
# processing_action_tokenizer.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/physical-intelligence/fast:
# - processing_action_tokenizer.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# tokenizer_config.json:   0%|          | 0.00/322 [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/3.00 [00:00<?, ?B/s]
# Actions shape: (10, 8)

# %% [markdown]
# # Working with a live model
#
#
# The following example shows how to create a live model from a checkpoint and compute training loss. First, we are going to demonstrate how to do it with fake data.

# %%
config = _config.get_config("pi0_aloha_sim")

checkpoint_dir = download.maybe_download("gs://openpi-assets/checkpoints/pi0_aloha_sim")
key = jax.random.key(0)

# Create a model from the checkpoint.
model = config.model.load(_model.restore_params(checkpoint_dir / "params"))

# We can create fake observations and actions to test the model.
obs, act = config.model.fake_obs(), config.model.fake_act()

# Sample actions from the model.
loss = model.compute_loss(key, obs, act)
print("Loss shape:", loss.shape)

# %% [markdown]
# Now, we are going to create a data loader and use a real batch of training data to compute the loss.

# %%
# Reduce the batch size to reduce memory usage.
config = dataclasses.replace(config, batch_size=2)

# Load a single batch of data. This is the same data that will be used during training.
# NOTE: In order to make this example self-contained, we are skipping the normalization step
# since it requires the normalization statistics to be generated using `compute_norm_stats`.
loader = _data_loader.create_data_loader(config, num_batches=1, skip_norm_stats=True)
obs, act = next(iter(loader))

# Sample actions from the model.
loss = model.compute_loss(key, obs, act)

# Delete the model to free up memory.
del model

print("Loss shape:", loss.shape)
